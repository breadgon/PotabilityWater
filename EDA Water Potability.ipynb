# %% [markdown]
# # Exploratory Data Analyst Water Potability

# %%
#Import Library

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
water = pd.read_csv('water_potability.csv')
water
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
water.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
water.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
water.drop(columns=['Sulfate'], inplace=True)

# %%
water
# Out:
#             ph    Hardness        Solids  Chloramines  Conductivity  \
# 0          NaN  204.890455  20791.318981     7.300212    564.308654
# 1     3.716080  129.422921  18630.057858     6.635246    592.885359
# 2     8.099124  224.236259  19909.541732     9.275884    418.606213
# 3     8.316766  214.373394  22018.417441     8.059332    363.266516
# 4     9.092223  181.101509  17978.986339     6.546600    398.410813
# ...        ...         ...           ...          ...           ...
# 3271  4.668102  193.681735  47580.991603     7.166639    526.424171
# 3272  7.808856  193.553212  17329.802160     8.061362    392.449580
# 3273  9.419510  175.762646  33155.578218     7.350233    432.044783
# 3274  5.126763  230.603758  11983.869376     6.303357    402.883113
# 3275  7.874671  195.102299  17404.177061     7.509306    327.459760
#
#       Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0          10.379783        86.990970   2.963135           0
# ...

# %%
# Fill NaN with forward and backward data

water.fillna(method='pad', inplace=True)
water.fillna(method='bfill', inplace=True)

# %%
water
# Out:
#             ph    Hardness        Solids  Chloramines  Conductivity  \
# 0     3.716080  204.890455  20791.318981     7.300212    564.308654
# 1     3.716080  129.422921  18630.057858     6.635246    592.885359
# 2     8.099124  224.236259  19909.541732     9.275884    418.606213
# 3     8.316766  214.373394  22018.417441     8.059332    363.266516
# 4     9.092223  181.101509  17978.986339     6.546600    398.410813
# ...        ...         ...           ...          ...           ...
# 3271  4.668102  193.681735  47580.991603     7.166639    526.424171
# 3272  7.808856  193.553212  17329.802160     8.061362    392.449580
# 3273  9.419510  175.762646  33155.578218     7.350233    432.044783
# 3274  5.126763  230.603758  11983.869376     6.303357    402.883113
# 3275  7.874671  195.102299  17404.177061     7.509306    327.459760
#
#       Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0          10.379783        86.990970   2.963135           0
# ...

# %%
water.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
# Use Scatter Plot

plt.figure(figsize=(15,5))
plt.scatter(water['Trihalomethanes'], water['Chloramines'])

plt.xlabel('Trihalomethanes')
plt.ylabel('Chloramines')
plt.title('Trihalomethanes Vs Chloramines')
plt.show()

# %%
plt.style.use('classic')

plt.figure(figsize=(15,7))
plt.scatter(water['ph'], water['Organic_carbon'], c=water['Potability'], s=75)

plt.xlabel('Ph')
plt.ylabel('Organic Carbon')
plt.title('Ph Vs Organic Carbon')
plt.show()

# %%
plt.style.use('default')
plt.figure(figsize=(15,8))


plt.subplot(3,1,1)
plt.scatter(water['ph'], water['Chloramines'])
plt.ylabel('Chloramines')


plt.subplot(3,1,2)
plt.scatter(water['ph'], water['Organic_carbon'])
plt.xlabel('ph')
plt.ylabel('Organic_carbon')


plt.subplot(3,1,3)
plt.scatter(water['ph'], water['Turbidity'])
plt.xlabel('ph')
plt.ylabel('Turbidity')

plt.show()

# %%
for i in range(len(water.columns)):
    plt.boxplot(water.iloc[:, i])
    x_name = water.columns[i]
    plt.xlabel(f'{x_name}')
    plt.show()

# %%
for i in range(len(water.columns)):
    plt.hist(water.iloc[:, i])
    x_name = water.columns[i]
    plt.title(f'{x_name}')
    plt.show()

# %%
var_potability = water['Potability'].value_counts()
var_potability
# Out:
# 0    1998
# 1    1278
# Name: Potability, dtype: int64

# %%
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize=(9, 8))

labels = ['Non_Potable', 'Potable']
ax.pie(var_potability, labels = labels, shadow = True, autopct='%.2f%%', startangle=70)
ax.set_title('Potability')
ax.legend()

plt.show()

# %%
water_potable = water[water['Potability'] == 1]
water_potable
# Out:
#             ph    Hardness        Solids  Chloramines  Conductivity  \
# 250   9.445130  145.805402  13168.529156     9.444471    592.659021
# 251   9.024845  128.096691  19859.676476     8.016423    451.143481
# 252   9.024845  169.974849  23403.637304     8.519730    475.573562
# 253   6.800119  242.008082  39143.403329     9.501695    376.456593
# 254   7.174135  203.408935  20401.102461     7.681806    315.549900
# ...        ...         ...           ...          ...           ...
# 3271  4.668102  193.681735  47580.991603     7.166639    526.424171
# 3272  7.808856  193.553212  17329.802160     8.061362    392.449580
# 3273  9.419510  175.762646  33155.578218     7.350233    432.044783
# 3274  5.126763  230.603758  11983.869376     6.303357    402.883113
# 3275  7.874671  195.102299  17404.177061     7.509306    327.459760
#
#       Organic_carbon  Trihalomethanes  Turbidity  Potability
# 250         8.606397        77.577460   3.875165           1
# ...

# %%
water_potable = water_potable.mean()
water_potable
# Out:
# ph                     7.055741
# Hardness             195.800744
# Solids             22383.991018
# Chloramines            7.169338
# Conductivity         425.383800
# Organic_carbon        14.160893
# Trihalomethanes       66.668898
# Turbidity              3.968328
# Potability             1.000000
# dtype: float64

# %%
water_potable['Solids'] = water_potable['Solids']/100
water_potable
# Out:
# ph                   7.055741
# Hardness           195.800744
# Solids             223.839910
# Chloramines          7.169338
# Conductivity       425.383800
# Organic_carbon      14.160893
# Trihalomethanes     66.668898
# Turbidity            3.968328
# Potability           1.000000
# dtype: float64

# %%
water_potable = pd.DataFrame(water_potable, columns = ['Potability'])
water_potable
# Out:
#                  Potability
# ph                 7.055741
# Hardness         195.800744
# Solids           223.839910
# Chloramines        7.169338
# Conductivity     425.383800
# Organic_carbon    14.160893
# Trihalomethanes   66.668898
# Turbidity          3.968328
# Potability         1.000000

# %%
water_potable = water_potable.drop(['Potability'])
water_potable
# Out:
#                  Potability
# ph                 7.055741
# Hardness         195.800744
# Solids           223.839910
# Chloramines        7.169338
# Conductivity     425.383800
# Organic_carbon    14.160893
# Trihalomethanes   66.668898
# Turbidity          3.968328

# %%
plt.style.use('fivethirtyeight')
water_potable.plot(kind='bar');

# %%
water_non_potable = water[water['Potability'] == 0]
water_non_potable
# Out:
#             ph    Hardness        Solids  Chloramines  Conductivity  \
# 0     3.716080  204.890455  20791.318981     7.300212    564.308654
# 1     3.716080  129.422921  18630.057858     6.635246    592.885359
# 2     8.099124  224.236259  19909.541732     9.275884    418.606213
# 3     8.316766  214.373394  22018.417441     8.059332    363.266516
# 4     9.092223  181.101509  17978.986339     6.546600    398.410813
# ...        ...         ...           ...          ...           ...
# 3112  6.616731  195.096968  34277.760400     7.632639    417.465080
# 3113  7.734569  230.919506  21776.594455     6.908591    395.114961
# 3114  6.971577  185.906938  27959.987873     7.214510    414.067354
# 3115  4.709187  179.141018  22291.418577     6.774276    371.264843
# 3116  5.230003  176.714023  27971.891806     7.597981    440.355374
#
#       Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0          10.379783        86.990970   2.963135           0
# ...

# %%
water_non_potable = water_non_potable.mean()
water_non_potable
# Out:
# ph                     7.078418
# Hardness             196.733292
# Solids             21777.490788
# Chloramines            7.092175
# Conductivity         426.730454
# Organic_carbon        14.364335
# Trihalomethanes       66.265190
# Turbidity              3.965800
# Potability             0.000000
# dtype: float64

# %%
water_non_potable['Solids'] = water_non_potable['Solids']/100
water_non_potable
# Out:
# ph                   7.078418
# Hardness           196.733292
# Solids             217.774908
# Chloramines          7.092175
# Conductivity       426.730454
# Organic_carbon      14.364335
# Trihalomethanes     66.265190
# Turbidity            3.965800
# Potability           0.000000
# dtype: float64

# %%
water_non_potable = pd.DataFrame(water_non_potable, columns=['Non Potability'])

# %%
water_non_potable
# Out:
#                  Non Potability
# ph                     7.078418
# Hardness             196.733292
# Solids               217.774908
# Chloramines            7.092175
# Conductivity         426.730454
# Organic_carbon        14.364335
# Trihalomethanes       66.265190
# Turbidity              3.965800
# Potability             0.000000

# %%
water_non_potable = water_non_potable.drop(['Potability'])

# %%
water_non_potable
# Out:
#                  Non Potability
# ph                     7.078418
# Hardness             196.733292
# Solids               217.774908
# Chloramines            7.092175
# Conductivity         426.730454
# Organic_carbon        14.364335
# Trihalomethanes       66.265190
# Turbidity              3.965800

# %%
plt.style.use('fivethirtyeight')
water_non_potable.plot(kind='bar');

# %%
concat_water = pd.concat([water_potable, water_non_potable], axis=1)
concat_water
# Out:
#                  Potability  Non Potability
# ph                 7.055741        7.078418
# Hardness         195.800744      196.733292
# Solids           223.839910      217.774908
# Chloramines        7.169338        7.092175
# Conductivity     425.383800      426.730454
# Organic_carbon    14.160893       14.364335
# Trihalomethanes   66.668898       66.265190
# Turbidity          3.968328        3.965800

# %%
plt.style.use('default')

width = 0.4
x = np.arange(len(concat_water.index))

fig1, ax1 = plt.subplots(figsize=(12,5))
reacts1 = ax1.bar(x - width/2, concat_water['Potability'], width, label = 'Potable')
reacts2 = ax1.bar(x + width/2, concat_water['Non Potability'], width, label = 'Non Potable')
ax1.set_title('Potability of Water', pad=25, fontweight='bold')
ax1.set_ylabel('Potability')
ax1.set_xticks(x)
ax1.set_xticklabels(concat_water.index, rotation=30)
ax1.legend()

ax1.bar_label(reacts1, padding=2, rotation=30)
ax1.bar_label(reacts2, padding=2, rotation=30)

fig1.tight_layout()

plt.show()
